# %% [markdown]
# # Introduction

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(18, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# # Comparing across all degree categories

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16,20))

for i in range(0,18,3):
    i2 = int(i/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i2]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i2]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[i2])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i2 == 0:
        ax.text(2005, 87, 'Women')
        ax.text(2002, 8, 'Men')
    elif i2 == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
        
for i in range(1,16,3):
    i2 = int((i-1)/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i2]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i2]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[i2])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i2 == 0:
        ax.text(2003, 78, 'Women')
        ax.text(2005, 18, 'Men')
        
for i in range(1,18,3):
    i2 = int((i-1)/3)
    ax = fig.add_subplot(6,3,i+2)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i2]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i2]], c=cb_orange, label='Men', linewidth=3)
    for key,spine in ax.spines.items():
        spine.set_visible(False)    
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[i2])
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i2 == 0:
        ax.text(2003, 90, 'Women')
        ax.text(2005, 5, 'Men')
    elif i2 == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2003, 30, 'Women')

# %%
#My version.

stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16,20))

for i in range(0,18,3):
    cat_index = int(i/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[stem_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(stem_cats[cat_index])
    
    if cat_index == 0:
        ax.text(2005,85,"Women")
        ax.text(2005,10,"Men")
    if cat_index == 5:    
        ax.text(2005,85,"Men")
        ax.text(2005,10,"Women") 
        
for i in range(1,16,3):
    cat_index = int((i-1)/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[lib_arts_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(lib_arts_cats[cat_index])
    
    if cat_index == 0:
        ax.text(2005,80,"Women")
        ax.text(2005,18,"Men")
    if cat_index == 4:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women") 
        
for i in range(1,18,3): #3 steps beginning 1 until 18. Add 2 to determine subplot location.
    cat_index = int((i-1)/3) #Make i divisible by 3 to set as index.
    ax = fig.add_subplot(6,3,i+2)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[other_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(other_cats[cat_index])
    
    if cat_index == 0:
        ax.text(2005,90,"Women")
        ax.text(2005,5,"Men")
    if cat_index == 5:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women")

# %% [markdown]
# # Hide axis labels

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16,20))

# Generate first column of line charts for STEM degrees.
for i in range(0,18,3):
    cat_index = int(i/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[stem_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(stem_cats[cat_index])
    
    if cat_index == 0:
        ax.text(2005,85,"Women")
        ax.text(2005,10,"Men")
    if cat_index == 5:    
        ax.text(2005,85,"Men")
        ax.text(2005,10,"Women")
        ax.tick_params(labelbottom="on")

# Generate first column of line charts for Liberal Arts degrees.
for i in range(1,16,3):
    cat_index = int((i-1)/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[lib_arts_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(lib_arts_cats[cat_index])
    
    if cat_index == 0:
        ax.text(2005,80,"Women")
        ax.text(2005,18,"Men")
    if cat_index == 4:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women") 
        ax.tick_params(labelbottom="on")

# Generate first column of line charts for Other degrees.
for i in range(1,18,3): #3 steps beginning 1 until 18. Add 2 to determine subplot location.
    cat_index = int((i-1)/3) #Make i divisible by 3 to set as index.
    ax = fig.add_subplot(6,3,i+2)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[other_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(other_cats[cat_index])
    
    if cat_index == 0:
        ax.text(2005,90,"Women")
        ax.text(2005,5,"Men")
    if cat_index == 5:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women")
        ax.tick_params(labelbottom="on")

# %% [markdown]
# # Setting y-axis labels

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16,20))

# Generate first column of line charts for STEM degrees.
for i in range(0,18,3):
    cat_index = int(i/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[stem_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(stem_cats[cat_index])
    ax.set_yticks([0,100])
    
    if cat_index == 0:
        ax.text(2005,85,"Women")
        ax.text(2005,10,"Men")
    if cat_index == 5:    
        ax.text(2005,85,"Men")
        ax.text(2005,10,"Women")
        ax.tick_params(labelbottom="on")

# Generate first column of line charts for Liberal Arts degrees.
for i in range(1,16,3):
    cat_index = int((i-1)/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[lib_arts_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(lib_arts_cats[cat_index])
    ax.set_yticks([0,100])
    
    if cat_index == 0:
        ax.text(2005,80,"Women")
        ax.text(2005,18,"Men")
    if cat_index == 4:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women") 
        ax.tick_params(labelbottom="on")

# Generate first column of line charts for Other degrees.
for i in range(1,18,3): #3 steps beginning 1 until 18. Add 2 to determine subplot location.
    cat_index = int((i-1)/3) #Make i divisible by 3 to set as index.
    ax = fig.add_subplot(6,3,i+2)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[other_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(other_cats[cat_index])
    ax.set_yticks([0,100])
    
    if cat_index == 0:
        ax.text(2005,90,"Women")
        ax.text(2005,5,"Men")
    if cat_index == 5:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women")
        ax.tick_params(labelbottom="on")

# %% [markdown]
# # Setting a horizontal line

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)

fig = plt.figure(figsize=(16,20))

# Generate first column of line charts for STEM degrees.
for i in range(0,18,3):
    cat_index = int(i/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[stem_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[stem_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(stem_cats[cat_index])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3)
    
    if cat_index == 0:
        ax.text(2005,85,"Women")
        ax.text(2005,10,"Men")
    if cat_index == 5:    
        ax.text(2005,85,"Men")
        ax.text(2005,10,"Women")
        ax.tick_params(labelbottom="on")

# Generate first column of line charts for Liberal Arts degrees.
for i in range(1,16,3):
    cat_index = int((i-1)/3)
    ax = fig.add_subplot(6,3,i+1)
    ax.plot(women_degrees["Year"], women_degrees[lib_arts_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[lib_arts_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(lib_arts_cats[cat_index])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3)

    if cat_index == 0:
        ax.text(2005,80,"Women")
        ax.text(2005,18,"Men")
    if cat_index == 4:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women") 
        ax.tick_params(labelbottom="on")

# Generate first column of line charts for Other degrees.
for i in range(1,18,3): #3 steps beginning 1 until 18. Add 2 to determine subplot location.
    cat_index = int((i-1)/3) #Make i divisible by 3 to set as index.
    ax = fig.add_subplot(6,3,i+2)
    ax.plot(women_degrees["Year"], women_degrees[other_cats[cat_index]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-(women_degrees[other_cats[cat_index]]), label="Men", c=cb_orange, linewidth=3)
    ax.set_ylim(0,100)
    ax.set_xlim(1970,2010)
    ax.tick_params(top="off", bottom="off", left="off", right="off", labelbottom="off") #remove tick marks
    for key,spine in ax.spines.items(): #remove borders
        spine.set_visible(False)
    ax.set_title(other_cats[cat_index])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255,171/255,171/255), alpha=0.3)

    if cat_index == 0:
        ax.text(2005,90,"Women")
        ax.text(2005,5,"Men")
    if cat_index == 5:    
        ax.text(2005,70,"Men")
        ax.text(2005,30,"Women")
        ax.tick_params(labelbottom="on")
